# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\JM025575\\Python Practice\\Python Programming Course'

# %%
movies = pd.read_csv('P4-Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                         559 non-null object
# Genre                        559 non-null object
# Rotten Tomatoes Ratings %    559 non-null int64
# Audience Ratings %           559 non-null int64
# Budget (million $)           559 non-null int64
# Year of release              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', \
                  'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
#change data type
movies.Film = movies.Film.astype('category')

# %%
movies.Genre = movies.Genre.astype('category')

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories #unique values in the cateory
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
#Working with Jointplots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'hex')

# %%
#Histograms

# %%
m1 = sns.distplot(movies.AudienceRating, bins = 15)

# %%
n1 = plt.hist(movies.AudienceRating, bins = 15)

# %%
sns.set_style('darkgrid') #change background styling

# %%
#Stacked Histograms

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 15)
plt.show()

# %%
[movies[movies.Genre == 'Drama'].BudgetMillions, 
movies[movies.Genre == 'Action'].BudgetMillions]
plt.hist([movies[movies.Genre == 'Drama'].BudgetMillions, movies[movies.Genre == 'Action'].BudgetMillions], stacked = True, bins = 15)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)
    
h = plt.hist(list1, bins = 30, stacked = True, rwidth = 1, label = mylabels)
plt.legend()
plt.show()

# %%
#KDE Plot

# %%
vis1 = sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating', fit_reg = False, hue = 'Genre', size = 7, aspect = 1)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating)

# %%
k2 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, cmap = 'Reds' )

# %%
#Subplots

# %%
k3 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
f, axes = plt.subplots(1,2, figsize = (12,6), sharex = True, sharey = True) #f is the figure and axes is the array of the data for the charts
k3 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0])
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax = axes[1])
k3.set(xlim = (-20, 160))
# Out:
# [(-20, 160)]

# %%
#Violin Plots

# %%
z = sns.violinplot(data = movies[movies.Genre == 'Drama'], x = 'Year', y = 'CriticRating')

# %%
w = sns.boxplot(data = movies[movies.Genre == 'Drama'], x = 'Year', y = 'CriticRating')

# %%
#Facet Grid

# %%
#g = sns.FacetGrid(movies, row = 'Genre', hue = 'Genre')
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s = 50, linewidth = 0.5, edgecolor = 'black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)

# %%
#Controlling axes and adding diagonals
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s = 50, linewidth = 0.5, edgecolor = 'black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c = 'gray', ls = '--')
g.add_legend()

# %%
#Building Dashboards

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize = (15,15))
k3 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax = axes[0,0])
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax = axes[0,1])
z = sns.violinplot(data = movies[movies.Genre == 'Drama'], x = 'Year', y = 'BudgetMillions', ax = axes[1,0])
k2 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, cmap = 'Reds', ax = axes[1,1] )
k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap = 'Reds', ax = axes[1,1])
#for non seaborn plots, axes.[1,1].hist(movies.CriticRating, bins = 15)
k3.set(xlim = (-20, 160))
k1.set(xlim = (-20, 160))
plt.show()

# %%
#styling tips

# %%
sns.set_style('dark', {'axes.facecolor': 'black'})
f, axes = plt.subplots(2,2, figsize = (15,15))
#Plot 0,0
k3 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, shade = True, shade_lowest = True, cmap = 'inferno', ax = axes[0,0])
k3b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, cmap = 'cool', ax = axes[0,0])

#Plot 0,1
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, shade = True, shade_lowest = True, cmap = 'inferno', ax = axes[0,1])
k1b = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, cmap = 'cool', ax = axes[0,1])

#Plot 1,0
z = sns.violinplot(data = movies, x = 'Year', y = 'BudgetMillions', ax = axes[1,0], palette = 'YlOrRd')

#Plot 1,1
k2 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, cmap = 'Blues_r', ax = axes[1,1] )
k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap = 'gist_gray_r', ax = axes[1,1])
#for non seaborn plots, axes.[1,1].hist(movies.CriticRating, bins = 15)

k3.set(xlim = (-20, 160))
k1.set(xlim = (-20, 160))
plt.show()

# %%
#Finishing Touches

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

sns.set_style('whitegrid')
fig, ax = plt.subplots() #now you can easily change size of figure
fig.set_size_inches(11.7, 8.27)
h = plt.hist(list1, bins = 30, stacked = True, rwidth = 1, label = mylabels)
plt.title('Movie Budget Distribution', fontsize = 18, color = 'DarkBlue', fontname = 'Console')
plt.ylabel('Number of Movies', fontsize = 14, color = 'Red')
plt.xlabel('Budget', fontsize = 14, color = 'Green')
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.legend(frameon = True, fancybox = True, shadow = True, framealpha = 1, prop = {'size':15})
plt.show()

# %% [markdown]
# ## Homework

# %%
#Read in data
mov = pd.read_csv('P4-Section6-Homework-Dataset.csv', encoding = 'latin1')

# %%
mov.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
mov.shape
# Out:
# (608, 18)

# %%
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# Day of Week               608 non-null object
# Director                  608 non-null object
# Genre                     608 non-null object
# Movie Title               608 non-null object
# Release Date              608 non-null object
# Studio                    608 non-null object
# Adjusted Gross ($mill)    608 non-null object
# Budget ($mill)            608 non-null float64
# Gross ($mill)             608 non-null object
# IMDb Rating               608 non-null float64
# MovieLens Rating          608 non-null float64
# Overseas ($mill)          608 non-null object
# Overseas%                 608 non-null float64
# Profit ($mill)            608 non-null object
# Profit%                   608 non-null float64
# Runtime (min)             608 non-null int64
# US ($mill)                608 non-null float64
# Gross % US                608 non-null float64
# ...

# %%
mov.describe()
# Out:
#        Budget ($mill)  IMDb Rating  MovieLens Rating   Overseas%  \
# count      608.000000   608.000000        608.000000  608.000000
# mean        92.467928     6.923849          3.340378   57.698849
# std         59.421407     0.925890          0.454071   12.334237
# min          0.600000     3.600000          1.490000   17.200000
# 25%         45.000000     6.375000          3.037500   49.900000
# 50%         80.000000     6.900000          3.365000   58.200000
# 75%        130.000000     7.600000          3.672500   66.300000
# max        300.000000     9.200000          4.500000  100.000000
#
#             Profit%  Runtime (min)  US ($mill)  Gross % US
# count    608.000000     608.000000  608.000000  608.000000
# mean     719.278783     117.781250  167.135197   42.301151
# std     1942.807248      23.179122   92.465903   12.334237
# min        7.700000      30.000000    0.000000    0.000000
# 25%      201.850000     100.000000  106.950000   33.700000
# ...

# %%
vis1 = sns.factorplot(data = mov, x = 'Day of Week', kind = 'count', size =10)

# %%
mov.Studio.unique()
# Out:
# array(['Buena Vista Studios', 'Lionsgate', 'Sony', 'Universal',
#        'Paramount Pictures', 'WB', 'Weinstein Company',
#        'UA Entertainment', 'WB/New Line', 'New Line Cinema', 'Fox',
#        'TriStar', 'Relativity Media', 'Screen Gems', 'StudioCanal',
#        'Fox Searchlight Pictures', 'MiraMax', 'Path_ Distribution',
#        'DreamWorks', 'Lionsgate Films', 'Revolution Studios',
#        'Dimension Films', 'USA', 'Lionsgate/Summit',
#        'Sony Picture Classics', 'Pacific Data/DreamWorks', 'Disney',
#        'Art House Studios', 'Colombia Pictures', 'Gramercy Pictures',
#        'Summit Entertainment', 'Vestron Pictures', 'MGM', 'Orion', 'IFC',
#        'New Market Films'], dtype=object)

# %%
len(mov.Studio.unique())
# Out:
# 36

# %%
len(mov.Genre.unique())
# Out:
# 15

# %%
#Filter down to Genre's and Studios we want
#mov2 = mov[(mov.Studio == 'Fox') | (mov.Studio == 'WB') | (mov.Studio == 'Fox')]
genre_filters = ['action', 'adventure', 'animation', 'comedy', 'drama']
mov2 = mov[mov.Genre.isin(genre_filters)]

# %%
studio_filters = ['Buena Vista Studios', 'Fox', 'Paramount Pictures', 'Sony', 'Universal', 'WB']
mov3 = mov2[mov2.Studio.isin(studio_filters)]

# %%
print(mov3.Studio.unique())
# Out:
# ['Buena Vista Studios' 'Sony' 'Universal' 'WB' 'Paramount Pictures' 'Fox']

# %%
len(mov3)
# Out:
# 423

# %%
sns.set(style = 'darkgrid', palette = 'muted', color_codes = True)

ax = sns.boxplot(data = mov3, x = 'Genre', y = 'Gross % US', orient = 'v', color = 'lightgray', showfliers = False)
plt.setp(ax.artists, alpha = 0.5)

sns.stripplot(x = 'Genre', y = 'Gross % US', data = mov3, jitter = True, size = 6, linewidth = 0, hue = 'Studio')

ax.axes.set_title('Domestic Gross % by Genre', fontsize = 18)
ax.set_xlabel('Genre', fontsize = 12)
ax.set_ylabel('Gross % US', fontsize = 12)
ax.legend(bbox_to_anchor = (1.05, 1), loc = 2)
